# %% [markdown]
# ## Import Libraries :

# %%
import numpy as np
import pickle
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras import backend as K
from sklearn.utils import shuffle
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import cv2
from skimage import io
from keras.preprocessing.image import load_img
from keras.models import load_model

# %% [markdown]
# ## Reading the dataset from Folder :

# %%
import os
data_path=r"C:\Users\yadav\OneDrive\Desktop\Prepration\DL_Datasets\PPT\Apple Dataset\color"
categories=os.listdir(data_path)

labels=[i for i in range(len(categories))]
label_dict=dict(zip(categories,labels))
print("Labels",labels)
print(categories)
print(label_dict)
# Out:
# Labels [0, 1, 2, 3]
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy']
# {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3}

# %% [markdown]
# ## Uploading the images and the labels :

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
images=[]
labels=[]

for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
    
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        img= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images.append(img)
        labels.append(label_dict[category])

# %%
print('Original Images : ',len(images))
print('Labels : ',len(labels))
# Out:
# Original Images :  3171
# Labels :  3171

# %%
plt.imshow(images[3170])

# %% [markdown]
# ## Enhancement technique :

# %%
CLAHE_images=[]
#img = cv2.imread('images/retina.jpg', 1)
for img in images:
    
#Converting image to LAB Color so CLAHE can be applied to the luminance channel
    lab_img= cv2.cvtColor(img, cv2.COLOR_RGB2LAB)

#Splitting the LAB image to L, A and B channels, respectively
    l, a, b = cv2.split(lab_img)

#plt.hist(l.flat, bins=100, range=(0,255))
###########Histogram Equlization#############
#Apply histogram equalization to the L channel
    #equ = cv2.equalizeHist(l)

#plt.hist(equ.flat, bins=100, range=(0,255))
#Combine the Hist. equalized L-channel back with A and B channels
    #updated_lab_img1 = cv2.merge((equ,a,b))

#Convert LAB image back to color (RGB)
    #hist_eq_img = cv2.cvtColor(updated_lab_img1, cv2.COLOR_LAB2BGR)

###########CLAHE#########################
#Apply CLAHE to L channel
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    clahe_img = clahe.apply(l)
#plt.hist(clahe_img.flat, bins=100, range=(0,255))

#Combine the CLAHE enhanced L-channel back with A and B channels
    updated_lab_img2 = cv2.merge((clahe_img,a,b))

#Convert LAB image back to color (RGB)
    CLAHE_img = cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2RGB)


    #cv2.imshow("Original
    #Original_images.append(img)
    
    #cv2.imshow("Equalized image", hist_eq_img)
    #hist_eq_images.append(hist_eq_img)
    #cv2.imshow('CLAHE Image', CLAHE_img)
    CLAHE_images.append(CLAHE_img)
    #cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
print('Enhancement Images : ',len(CLAHE_images))
print('Labels : ',len(labels))
# Out:
# Enhancement Images :  3171
# Labels :  3171

# %%
plt.imshow(CLAHE_images[3170])
plt.axis('off')
plt.show()

# %%
plt.imshow(CLAHE_images[3170])
plt.axis('off')
plt.show()

# %% [markdown]
# ## Segmentation using Kmeans Cluster :

# %%
segmented=[]
for image_or in range(len(CLAHE_images)):
    
    image_or = cv2.resize(CLAHE_images[image_or],(256,256))
    image2 = cv2.GaussianBlur(image_or,(5,5),0)
    image_f = np.array(image2)
    image = cv2.cvtColor(image2,cv2.COLOR_RGB2HSV)
    z = image.reshape((-1,3))
    Z = np.float32(z)
    cr = (cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER,100,1.0)
    k = 2 
    ret,label,center = cv2.kmeans(Z,k,None,cr,10,cv2.KMEANS_RANDOM_CENTERS)

    center = np.uint8(center)
    res = center[label.flatten()]
    res = np.array(res)
    res3 = res.reshape((image.shape))

    mask = cv2.inRange(res3, (0,100,0), (173, 255, 170))
    imask = mask>0
    green = np.zeros_like(image,np.uint8)
    green[imask] = image[imask]


    res4 = green
    for i in range(256):
        for j in range(256):
            for k in range(3):
                if ((res4[i][j][k] == 0 or res4[i][j][k] == 0 or res4[i][j][k] == 0)):
                    image_or[i][j][k]=0
    segmented.append(image_or)

# %%
print('Segmented1 Images : ',len(segmented))
print('Labels : ',len(labels))
# Out:
# Segmented1 Images :  3171
# Labels :  3171

# %%
for i in range(0,10):
    plt.subplot(2,5,i+1)
    plt.imshow(segmented[i])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

# %% [markdown]
# ### To Save a image :
# **for i in range(len(segmented1)):\
#     plt.imsave('Apple Leaf Disease Dataset/Segmented_images/seg{}.png'.format(i),segmented1[i])**

# %% [markdown]
# ## SURF Feature Extraction :

# %%
#path_1=r'C:\Users\yadav\OneDrive\Desktop\train.jpg'

# %%
#i=cv2.imread(path_1)
#g=cv2.cvtColor(i,cv2.COLOR_BGR2GRAY)

# %%
surf = cv2.SIFT_create()

# %%
sf_seg_img =[]
for sf_img in segmented:
    keypoints,descriptors=surf.detectAndCompute(sf_img,None)
    img=cv2.drawKeypoints(sf_img,keypoints,None)
    sf_seg_img.append(img)

# %%
print('Surf Segmented Images : ',len(sf_seg_img))
print('Labels : ',len(labels))
# Out:
# Surf Segmented Images :  3171
# Labels :  3171

# %%
for i in range(0,25):
    plt.subplot(5,5,i+1)
    plt.imshow(sf_seg_img[i])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

# %%
sf_seg_img[1].shape
# Out:
# (256, 256, 3)

# %%
data=np.array(sf_seg_img)/255.0 #convert the pixel range to 0 and 1
data=np.reshape(data,(data.shape[0],data.shape[1],data.shape[2],data.shape[3])) #reshape into 4-D because neural network needs a 4-D array
target=np.array(labels)

# %%
data.shape
# Out:
# (3171, 256, 256, 3)

# %%
from keras.utils import np_utils
new_target=np_utils.to_categorical(target)

# %%
print('data Images : ',len(data))
print('target Labels : ',len(new_target))
# Out:
# data Images :  3171
# target Labels :  3171

# %% [markdown]
# ## Build CNN Structure :

# %%
model = Sequential()
inputShape = (256, 256, 3)
chanDim = -1
if K.image_data_format() == "channels_first":
    inputShape = (256, 256, 3)
    chanDim = 1
model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(4))
model.add(Activation("softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# activation (Activation)      (None, 256, 256, 32)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 85, 85, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 85, 85, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 85, 85, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 42, 42, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 42, 42, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 42, 42, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 42, 42, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 56448)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              57803776
# _________________________________________________________________
# activation_5 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_6 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 58,091,396
# Trainable params: 58,088,516
# Non-trainable params: 2,880
# _________________________________________________________________

# %% [markdown]
# ## Adam Optimization :

# %%
opt = Adam(learning_rate=0.001, 
           beta_1=0.9, 
           beta_2=0.999, 
           epsilon=1e-07, 
           amsgrad=False)

# %% [markdown]
# ## Compile Model :

# %%
# distribution
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

# %% [markdown]
# ## Split the dataset

# %%
from sklearn.model_selection import train_test_split
train_Data,test_Data,train_Target,test_Target=train_test_split(data,new_target,test_size=0.2)

# %% [markdown]
# ## Data Augmentation :

# %%
epoch = 20

bs=32
augmentation = ImageDataGenerator(rotation_range=20,
                                 zoom_range=0.15,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 shear_range=0.15,
                                 horizontal_flip=True,
                                 fill_mode='nearest')

# %% [markdown]
# ## Save the Model

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("apple_cnn.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## train the model

# %%
history = model.fit_generator(
    augmentation.flow(train_Data, train_Target, batch_size=bs),
    validation_data=(test_Data, test_Target),
    steps_per_epoch=len(train_Data) // bs,
    epochs=epoch, verbose=1,
    callbacks=[checkpoint,early]
    )
# Out:
# Epoch 1/20
# 79/79 [==============================] - ETA: 0s - loss: 1.5138 - accuracy: 0.5691WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 428s 5s/step - loss: 1.5138 - accuracy: 0.5691 - val_loss: 1.3744 - val_accuracy: 0.5102
# Epoch 2/20
# 79/79 [==============================] - ETA: 0s - loss: 1.2232 - accuracy: 0.5950WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 428s 5s/step - loss: 1.2232 - accuracy: 0.5950 - val_loss: 9.6508 - val_accuracy: 0.2189
# Epoch 3/20
# 79/79 [==============================] - ETA: 0s - loss: 1.2197 - accuracy: 0.6098WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 440s 6s/step - loss: 1.2197 - accuracy: 0.6098 - val_loss: 74.8275 - val_accuracy: 0.5087
# Epoch 4/20
# 79/79 [==============================] - ETA: 0s - loss: 1.2459 - accuracy: 0.5935WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 375s 5s/step - loss: 1.2459 - accuracy: 0.5935 - val_loss: 255.2365 - val_accuracy: 0.5087
# Epoch 5/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1878 - accuracy: 0.6170WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 387s 5s/step - loss: 1.1878 - accuracy: 0.6170 - val_loss: 191.9105 - val_accuracy: 0.5102
# Epoch 6/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1884 - accuracy: 0.6174WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 384s 5s/step - loss: 1.1884 - accuracy: 0.6174 - val_loss: 247.2101 - val_accuracy: 0.6079
# Epoch 7/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1655 - accuracy: 0.6238WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 380s 5s/step - loss: 1.1655 - accuracy: 0.6238 - val_loss: 219.7438 - val_accuracy: 0.5969
# Epoch 8/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1018 - accuracy: 0.6406WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 377s 5s/step - loss: 1.1018 - accuracy: 0.6406 - val_loss: 5.8101 - val_accuracy: 0.6047
# Epoch 9/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1406 - accuracy: 0.6262WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 376s 5s/step - loss: 1.1406 - accuracy: 0.6262 - val_loss: 1.5300 - val_accuracy: 0.6315
# Epoch 10/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1004 - accuracy: 0.6350WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 381s 5s/step - loss: 1.1004 - accuracy: 0.6350 - val_loss: 15.9874 - val_accuracy: 0.2220
# Epoch 11/20
# 79/79 [==============================] - ETA: 0s - loss: 1.0991 - accuracy: 0.6282WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 374s 5s/step - loss: 1.0991 - accuracy: 0.6282 - val_loss: 715.8035 - val_accuracy: 0.6047
# Epoch 12/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1702 - accuracy: 0.6202WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 377s 5s/step - loss: 1.1702 - accuracy: 0.6202 - val_loss: 5.1224 - val_accuracy: 0.2110
# Epoch 13/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1828 - accuracy: 0.6202WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 379s 5s/step - loss: 1.1828 - accuracy: 0.6202 - val_loss: 14.1159 - val_accuracy: 0.2126
# Epoch 14/20
# 79/79 [==============================] - ETA: 0s - loss: 1.0869 - accuracy: 0.6454WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 379s 5s/step - loss: 1.0869 - accuracy: 0.6454 - val_loss: 2.2838 - val_accuracy: 0.2409
# Epoch 15/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1235 - accuracy: 0.6334WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 376s 5s/step - loss: 1.1235 - accuracy: 0.6334 - val_loss: 18.6950 - val_accuracy: 0.2094
# Epoch 16/20
# 79/79 [==============================] - ETA: 0s - loss: 1.0692 - accuracy: 0.6426WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 380s 5s/step - loss: 1.0692 - accuracy: 0.6426 - val_loss: 24.1451 - val_accuracy: 0.1953
# Epoch 17/20
# 79/79 [==============================] - ETA: 0s - loss: 1.0646 - accuracy: 0.6444WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 382s 5s/step - loss: 1.0646 - accuracy: 0.6444 - val_loss: 15.8155 - val_accuracy: 0.2142
# Epoch 18/20
# 79/79 [==============================] - ETA: 0s - loss: 1.1030 - accuracy: 0.6374WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 379s 5s/step - loss: 1.1030 - accuracy: 0.6374 - val_loss: 5.5143 - val_accuracy: 0.2016
# Epoch 19/20
# 79/79 [==============================] - ETA: 0s - loss: 1.0675 - accuracy: 0.6474WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 377s 5s/step - loss: 1.0675 - accuracy: 0.6474 - val_loss: 4.0927 - val_accuracy: 0.2945
# Epoch 20/20
# 79/79 [==============================] - ETA: 0s - loss: 1.0831 - accuracy: 0.6410WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 79/79 [==============================] - 373s 5s/step - loss: 1.0831 - accuracy: 0.6410 - val_loss: 1.8554 - val_accuracy: 0.2189

# %% [markdown]
# acc = history.history['accuracy']
# val_acc = history.history['validation accuracy']
# loss = history.history['loss']
# val_loss = history.history['validation_loss']
# epochs = range(1, len(acc) + 1)
# #Train and validation accuracy
# plt.plot(epochs, acc, 'b', label='Training accurarcy')
# plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
# plt.title('Training and Validation accurarcy')
# plt.legend()
#
# plt.figure()
# #Train and validation loss
# plt.plot(epochs, loss, 'b', label='Training loss')
# plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and Validation loss')
# plt.legend()
# plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'],'r',label='Traing_loss')
plt.plot(history.history['val_loss'],'y',label='Validation_loss')
plt.xlabel('No. of Epoch')
plt.ylabel("loss and val_loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'r',label='Traing_Accuracy')
plt.plot(history.history['val_accuracy'],'y',label='Validation_Accuracy')
plt.xlabel('No. of Epoch')
plt.ylabel("accuracy and val_Accuracy")
plt.legend()
plt.show()

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(test_Data,test_Target)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 20/20 [==============================] - 12s 583ms/step - loss: 1.8554 - accuracy: 0.2189
# Test Accuracy: 21.889764070510864

# %%
model.save("model.h5")

# %% [markdown]
# ## Detection of DISEASE on Leaf Image

# %%
from keras.models import load_model
model = load_model('model.h5')

# %%
path = r"C:\Users\yadav\OneDrive\Desktop\black_rot.jpg"
  from matplotlib import pyplot as plt
#Import image
image = cv2.imread(path)
lab_img= cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#Show the image with matplotlib
plt.imshow('lab_img')
plt.show()

# %%
import cv2
import numpy as np
model = load_model('model.h5')

model.compile(loss='catgorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

img = cv2.imread('lab_img')
img = cv2.resize(img,(256,256))
img = np.reshape(img,[1,256,256,3])

classes = model.predict_classes(img)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B615A42700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(classes) #Black rot
# Out:
# [1]
